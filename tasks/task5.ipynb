# %% [markdown]
# Загрузите датасет Титаник из файла "titanic.csv".
#
# Ваша задача:
# 1. Выведите первые 3 и последние 3 строки датасета, чтобы ознакомиться с его структурой
# 2. Напишите код, который выберет все строки, где пассажиры старше 30 лет
# 3. Выберите строки, где пассажиры путешествовали в первом классе
# 4. Найдите всех пассажиров, которые выжили и были женщинами
