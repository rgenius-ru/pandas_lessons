# %% [markdown]
# У вас есть CSV файл "task2.csv" с данными о продажах в магазине.
#
# Ваша задача - прочитать этот файл с помощью библиотеки pandas и
# выполнить несколько простых операций для анализа данных:
# 1. Выведите первые 10 строк данных
# 2. Получите информацию о данных (info)
# 3. Посчитайте общее количество продаж (результат - число int)
# 4. Посчитайте общее сумму продаж (результат - число int)
# 5. Найдите средний чек
